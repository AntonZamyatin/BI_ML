# %% [markdown]
# # HW 01

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import random
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### PCA plotting function

# %%
def plot_PCA(df, name, classes):
    x = df.drop(columns=['label'])
    y = df['label']

    pca = PCA(n_components=2)
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents
                  , columns = ['principal component 1', 'principal component 2'])

    finalDf = pd.concat([principalDf, df[['label']]], axis = 1)

    fig = plt.figure(figsize = (8,8))
    ax = fig.add_subplot(1,1,1) 
    ax.set_xlabel('Principal Component 1', fontsize = 15)
    ax.set_ylabel('Principal Component 2', fontsize = 15)
    ax.set_title(f'{name} dataset PCA', fontsize = 20)
    targets = classes
    colors = ['r', 'g', 'b']
    for target, color in zip(targets,colors):
        indicesToKeep = finalDf['label'] == target
        ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
                   , finalDf.loc[indicesToKeep, 'principal component 2']
                   , c = color
                   , s = 50)
    ax.legend(targets)
    ax.grid()

# %% [markdown]
# ## 1. kNN

# %%
def kNN(X, Y, unknown, k_list, default=False):
    """Returns list of classes determined by k neighbours"""
    def get_dist(a, b):
        """Euclidean distance"""
        return np.linalg.norm(a - b)
    
    def get_neighbours(X, unknown):
        """Returns pd.series with 10 neighbours for unknown sample"""
        return X.apply(lambda row: get_dist(row, unknown), axis=1).sort_values(ascending=True)[1:11]
    
    neib_indexes = get_neighbours(X, unknown).index
    classes_list = []
    for k in k_list:
        neib_classes = Y[neib_indexes[:k]].value_counts() # pd series [{class: number of neighbours}]
        num_of_equal = neib_classes.value_counts()[neib_classes.iloc[0]] 
    
        if num_of_equal > 1:
            if default and default in neib_classes.index[0:num_of_equal]:
                classes_list.append(default)
            else:
                classes_list.append(random.choice(neib_classes.index[0:num_of_equal]))
        else:
            classes_list.append(neib_classes.index[0])
    return classes_list

# %% [markdown]
# ## Leave-one-out cross validation
# $LOO(k, D) = {{\sum_{x_{i}\in D}{[h(x_i;D\setminus x_i; k) \ne y_i]}}\over {|D|}}$

# %%
def LOO(k_list, df, default=False):
    X = df.drop(columns=['label']) #input
    Y = df['label'] # output
    cnt = np.zeros(len(k_list))
    for i in df.index:
        unknown = X.iloc[i]
        kNN_list = kNN(X, Y, unknown, k_list, default)
        for j in range(len(k_list)):
            if kNN_list[j] != Y[i]:
                cnt[j] += 1
 
    return cnt/df.shape[0]

# %% [markdown]
# ## 1.1 Cancer dataset

# %%
df = pd.read_csv('cancer.csv')
df.head()
# Out:
#   label      1      2       3       4        5        6       7        8  \
# 0     M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710
# 1     M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017
# 2     M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790
# 3     M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520
# 4     M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430
#
#         9   ...        21     22      23      24      25      26      27  \
# 0  0.2419   ...     25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119
# 1  0.1812   ...     24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 2  0.2069   ...     23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 3  0.2597   ...     14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869
# 4  0.1809   ...     22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000
#
#        28      29       30
# 0  0.2654  0.4601  0.11890
# 1  0.1860  0.2750  0.08902
# ...

# %%
plot_PCA(df, "Cancer", ['M', 'B'])

# %%
k_ar = np.array(range(1,11))
LOO_vals = np.zeros(10)
LOO_vals = LOO(k_ar, df, default='M')
LOO_vals
# Out:
# array([0.08435852, 0.0913884 , 0.07381371, 0.07205624, 0.06678383,
#        0.0685413 , 0.0685413 , 0.06502636, 0.06678383, 0.06326889])

# %%
plt.xlabel('k')
plt.ylabel('LOO')
plt.title('Cancer dataset LOO CV')
plt.plot(k_ar, LOO_vals)
plt.show()

# %% [markdown]
# ## 1.2 Spam dataset

# %%
df = pd.read_csv('spam.csv')
df.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...    char_freq_:  char_freq_(  \
# 0             0.00            0.00  ...           0.00        0.000
# ...

# %%
plot_PCA(df, "Spam", [1, 0])

# %%
k_ar = np.array(range(1,11))
LOO_vals = LOO(k_ar, df, default=0)
LOO_vals
# Out:
# array([0.16865899, 0.19756575, 0.1845251 , 0.19126277, 0.18539448,
#        0.19886981, 0.19582699, 0.1973484 , 0.20256466, 0.19908715])

# %%
plt.xlabel('k')
plt.ylabel('LOO')
plt.title('Spam dataset LOO CV')
plt.plot(k_ar, LOO_vals)
plt.show()

# %% [markdown]
# ## 2. RN

# %%
def RN(X, Y, unknown, r_list, default=False):
    """Returns list of classes determined by radius"""
    def get_dist(a, b):
        """Euclidean distance"""
        return np.linalg.norm(a - b)
    
    def get_neighbours(X, unknown):
        """Returns pd.series with neighbours for unknown sample by distance"""
        return X.apply(lambda row: get_dist(row, unknown), axis=1).sort_values(ascending=True)[1:]
    
    neibours = get_neighbours(X, unknown)
    classes_list = []
    for r in r_list:
        neib_indexes = neibours[neibours <= r].index
        neib_classes = Y[neib_indexes].value_counts() # pd series [{class: number of neighbours}]
        if neib_classes.empty:
            classes_list.append(default)
        else:
            num_of_equal = neib_classes.value_counts()[neib_classes.iloc[0]] 
    
            if num_of_equal > 1:
                if default and default in neib_classes.index[0:num_of_equal]:
                    classes_list.append(default)
                else:
                    classes_list.append(random.choice(neib_classes.index[0:num_of_equal]))
            else:
                classes_list.append(neib_classes.index[0])
    return classes_list

# %%
def LOO_rn(r_list, df, default=False):
    X = df.drop(columns=['label']) #input
    Y = df['label'] # output
    cnt = np.zeros(len(r_list))
    for i in df.index:
        unknown = X.iloc[i]
        kNN_list = RN(X, Y, unknown, r_list, default)
        for j in range(len(r_list)):
            if kNN_list[j] != Y[i]:
                cnt[j] += 1
 
    return cnt/df.shape[0]

# %%
df_c = pd.read_csv('cancer.csv')
r_ar = np.array(range(0,40,5))
LOO_vals = np.zeros(len(r_ar))
LOO_vals = LOO_rn(r_ar, df_c, default='M')
LOO_vals
# Out:
# array([0.62741652, 0.6168717 , 0.46045694, 0.20035149, 0.10896309,
#        0.08611599, 0.08260105, 0.07205624])

# %%
plt.xlabel('Radius')
plt.ylabel('LOO')
plt.title('Cancer dataset LOO CV')
plt.plot(r_ar, LOO_vals)
plt.show()

# %%
df_c = pd.read_csv('cancer.csv')
r_ar = np.array(range(20,60,5))
LOO_vals = np.zeros(len(r_ar))
LOO_vals = LOO_rn(r_ar, df_c, default='M')
LOO_vals
# Out:
# array([0.10896309, 0.08611599, 0.08260105, 0.07205624, 0.0685413 ,
#        0.06678383, 0.06326889, 0.06326889])

# %%
plt.xlabel('Radius')
plt.ylabel('LOO')
plt.title('Cancer dataset LOO CV')
plt.plot(r_ar, LOO_vals)
plt.show()

# %%
df_c = pd.read_csv('cancer.csv')
r_ar = np.array(range(45,150,5))
LOO_vals = np.zeros(len(r_ar))
LOO_vals = LOO_rn(r_ar, df_c, default='M')
LOO_vals
# Out:
# array([0.06678383, 0.06326889, 0.06326889, 0.06678383, 0.0685413 ,
#        0.06326889, 0.07029877, 0.07381371, 0.07205624, 0.07908612,
#        0.07557118, 0.07732865, 0.07732865, 0.08260105, 0.08084359,
#        0.08084359, 0.08084359, 0.08260105, 0.08260105, 0.08260105,
#        0.08084359])

# %%
plt.xlabel('Radius')
plt.ylabel('LOO')
plt.title('Cancer dataset LOO CV')
plt.plot(r_ar, LOO_vals)
plt.show()

# %%
df_c = pd.read_csv('cancer.csv')
r_ar = np.array(range(43,77,2))
LOO_vals = np.zeros(len(r_ar))
LOO_vals = LOO_rn(r_ar, df_c, default='M')
LOO_vals
# Out:
# array([0.07029877, 0.06678383, 0.06678383, 0.06678383, 0.05975395,
#        0.06326889, 0.06326889, 0.06502636, 0.0685413 , 0.06502636,
#        0.0685413 , 0.0685413 , 0.06678383, 0.06326889, 0.07029877,
#        0.06678383, 0.07029877])

# %%
plt.xlabel('Radius')
plt.ylabel('LOO')
plt.title('Cancer dataset LOO CV')
plt.plot(r_ar, LOO_vals)
plt.show()

# %% [markdown]
# 52 - лучший радиус для RN алгоритма для cancer датасета

# %% [markdown]
# ## 3. Нормализация

# %%
input = df_c.drop(columns=['label'])
input = pd.DataFrame(MinMaxScaler().fit_transform(input))
norm_df = pd.concat([df_c[['label']], input], axis = 1)
norm_df.head()
# Out:
#   label         0         1         2         3         4         5         6  \
# 0     M  0.521037  0.022658  0.545989  0.363733  0.593753  0.792037  0.703140
# 1     M  0.643144  0.272574  0.615783  0.501591  0.289880  0.181768  0.203608
# 2     M  0.601496  0.390260  0.595743  0.449417  0.514309  0.431017  0.462512
# 3     M  0.210090  0.360839  0.233501  0.102906  0.811321  0.811361  0.565604
# 4     M  0.629893  0.156578  0.630986  0.489290  0.430351  0.347893  0.463918
#
#           7         8    ...           20        21        22        23  \
# 0  0.731113  0.686364    ...     0.620776  0.141525  0.668310  0.450698
# 1  0.348757  0.379798    ...     0.606901  0.303571  0.539818  0.435214
# 2  0.635686  0.509596    ...     0.556386  0.360075  0.508442  0.374508
# 3  0.522863  0.776263    ...     0.248310  0.385928  0.241347  0.094008
# 4  0.518390  0.378283    ...     0.519744  0.123934  0.506948  0.341575
#
#          24        25        26        27        28        29
# ...

# %%
plot_PCA(norm_df, "Cancer", ['M', 'B'])

# %% [markdown]
# ## 3.1 KNN на нормализованном датасете

# %%
k_ar = np.array(range(1,11))
LOO_vals = np.zeros(10)
LOO_vals = LOO(k_ar, norm_df, default='M')
LOO_vals
# Out:
# array([0.04745167, 0.05096661, 0.02987698, 0.03514938, 0.03339192,
#        0.03339192, 0.02987698, 0.02811951, 0.02987698, 0.02811951])

# %%
plt.xlabel('k')
plt.ylabel('LOO')
plt.title('Cancer normalised dataset LOO CV')
plt.plot(k_ar, LOO_vals)
plt.show()

# %% [markdown]
# Нормализованный датасет показывает лучшие результаты LOO CV

# %% [markdown]
# ## 3.2 RN На нормализованном датасете

# %%
r_ar = np.array(list(range(0,100,5)))/10
LOO_vals = np.zeros(len(r_ar))
LOO_vals = LOO_rn(r_ar, norm_df, default='M')
LOO_vals
# Out:
# array([0.62741652, 0.0685413 , 0.12478032, 0.29525483, 0.34973638,
#        0.3655536 , 0.37258348, 0.37258348, 0.37258348, 0.37258348,
#        0.37258348, 0.37258348, 0.37258348, 0.37258348, 0.37258348,
#        0.37258348, 0.37258348, 0.37258348, 0.37258348, 0.37258348])

# %%
plt.xlabel('Radius')
plt.ylabel('LOO')
plt.title('Cancer dataset LOO CV')
plt.plot(r_ar, LOO_vals)
plt.show()

# %%
r_ar = np.array(list(range(0,200,5)))/100
LOO_vals = np.zeros(len(r_ar))
LOO_vals = LOO_rn(r_ar, norm_df, default='M')
LOO_vals
# Out:
# array([0.62741652, 0.62741652, 0.62741652, 0.62038664, 0.5026362 ,
#        0.32513181, 0.19683656, 0.1370826 , 0.08611599, 0.08260105,
#        0.0685413 , 0.06151142, 0.0685413 , 0.06326889, 0.06678383,
#        0.07205624, 0.07908612, 0.08787346, 0.09666081, 0.10896309,
#        0.12478032, 0.14235501, 0.16168717, 0.18101933, 0.18980668,
#        0.20386643, 0.21616872, 0.24077329, 0.25834798, 0.27065026,
#        0.29525483, 0.30228471, 0.30579965, 0.31634446, 0.31810193,
#        0.32337434, 0.32864675, 0.33567663, 0.33919156, 0.34622144])

# %%
plt.xlabel('Radius')
plt.ylabel('LOO')
plt.title('Cancer dataset LOO CV')
plt.plot(r_ar, LOO_vals)
plt.show()

# %%
r_ar = np.array(list(range(30,80,5)))/100
LOO_vals = np.zeros(len(r_ar))
LOO_vals = LOO_rn(r_ar, norm_df, default='M')
LOO_vals
# Out:
# array([0.19683656, 0.1370826 , 0.08611599, 0.08260105, 0.0685413 ,
#        0.06151142, 0.0685413 , 0.06326889, 0.06678383, 0.07205624])

# %%
plt.xlabel('Radius')
plt.ylabel('LOO')
plt.title('Cancer dataset LOO CV')
plt.plot(r_ar, LOO_vals)
plt.show()

# %% [markdown]
# Для RN нормализованный датасет также показывает лучшие результаты LOO CV
