# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # HW 2
# ## 1. k-Means

# %%
def kMeans(df, k, vis=False):
    
    def visualise(df, cnt):
        colors = {0:'orange', 1:'blue', 2:'green', 3:'black', 4: 'cyan'}
        if 'cl' in df.columns:
            ax = df.plot(kind='scatter',x= 0,y= 1, c=df['cl'].apply(lambda x: colors[x]))
        else:
            ax = df.plot(kind='scatter',x= 0,y= 1, color='black')
        cnt.plot(ax = ax, kind='scatter',x = 0 ,y = 1,color = 'red', marker = '*', s = 200)
        plt.show()
    
    def centroids_init(df, k):
        N = len(df)
        cnt_coord = np.zeros((k, df.shape[1]))
        for i in range(k):
            for j in range(df.shape[1]):
                cnt_coord[i][j] = np.random.uniform(df.iloc[:, [j]].min(), 
                                                df.iloc[:, [j]].max())
        centroids = pd.DataFrame(cnt_coord)
        return centroids

    def get_dist(a, b):
        """Euclidean distance"""
        return np.linalg.norm(a - b)

    def get_clust(row, cnt):
        distances = cnt.apply(lambda x: get_dist(x.values, row.values), axis = 1)
        return distances.idxmin()
    
    def get_new_clusters(df, cnt):
        if 'cl' in df.columns:
            df_ = df.drop(['cl'], axis = 1)
        else:
            df_ = pd.DataFrame(df)
        clusters = df_.apply(lambda x: get_clust(x, cnt), axis = 1)
        df_['cl'] = clusters
        return df_

    def update_centroids(df, k):
        cnt_coord = np.zeros((k, df.shape[1] - 1))
        for i in range(k):
            for j in range(df.shape[1] - 1):
                cnt_coord[i][j] = df.loc[df['cl'] == i].iloc[:, [j]].mean()
        centroids = pd.DataFrame(cnt_coord)
        return centroids
    

    cnt = centroids_init(df, k)
    if vis: visualise(df, cnt)
    df_ = get_new_clusters(df, cnt)
    cnt_new = update_centroids(df_, k)
    if vis: visualise(df, cnt)
    
    while cnt_new.isna().values.any():
        if vis: print("Bad centroids")
        cnt_new = centroids_init(df.drop(['cl'], axis = 1), k)
        df_ = get_new_clusters(df, cnt_new)
        if vis: visualise(df, cnt_new)
        cnt = cnt_new
        cnt_new = update_centroids(df_, k)
    
    while (cnt != cnt_new).values.any():
        df_ = get_new_clusters(df_, cnt_new)
        cnt = cnt_new
        cnt_new = update_centroids(df_, k)
        if vis: visualise(df_, cnt)
    #print(cnt_new)
    return df

# %% [markdown]
# ## Blobs dataset

# %%
df = pd.read_csv('blobs.csv')
df.head()
# Out:
#           X         Y
# 0 -0.727696  1.403000
# 1 -1.875566  0.589247
# 2 -0.891047 -1.399924
# 3 -0.224115  0.868289
# 4 -0.465409  0.306718

# %%
kMeans(df, 5, True)
# Out:
# Bad centroids
# Bad centroids

# %% [markdown]
# Далее переделал функцию (kMeans2).
# Изменил
#
# инициализацию центроидов: первый центроид - случайный сампл, остальные - самплы на максимальном расстоянии от предыдущих;
#
# условия остановки: сходимость центроидов и ограничение на итерации;
#
# возвращает только классы, датафрейм не изменяется.

# %%
def kMeans2(df, k, vis=False):
    
    def visualise(df, cnt, cl=None):
        colors = {0:'orange', 1:'blue', 2:'green', 3:'black', 4: 'cyan', 5: '#0F0234', 6: '#05430F'}
        if not (cl is None):
            ax = df.plot(kind='scatter',x=df.columns[0], y=df.columns[1], c=cl.apply(lambda x: colors[x]))
        else:
            ax = df.plot(kind='scatter',x=df.columns[0], y=df.columns[1], color='black')
        cnt.plot(ax = ax, kind='scatter',x=df.columns[0] ,y=df.columns[1], color = 'red', marker = '*', s = 200)
        plt.show()
    
    def centroids_init(df, k):
        N = len(df)
        coords = df.copy()
        cnt_coord = []
        cnt_coord.append(df.iloc[random.randint(0, N)])
        for _ in range(1, k):
            N = len(coords)
            dist = np.zeros(N)
            for i in range(N):
                for j in range(len(cnt_coord)):
                    dist[i] += get_dist(coords.iloc[i], cnt_coord[j])
            ind = np.argmax(dist)
            cnt_coord.append(coords.iloc[ind])
            coords = coords.drop(coords.index[ind])
        centroids = pd.DataFrame(cnt_coord)
        centroids.index = list(range(k))
        return centroids

    def get_dist(a, b):
        """Euclidean distance"""
        return np.linalg.norm(a - b)

    def get_clust(row, cnt):
        distances = cnt.apply(lambda x: get_dist(x.values, row.values), axis = 1)
        return distances.idxmin()
    
    def get_new_clusters(df, cnt):
        clusters = df.apply(lambda x: get_clust(x, cnt), axis = 1)
        return clusters

    def update_centroids(df, cnt, cl, k):
        cnt_coord = cnt.copy()
        for i in range(k):
            for j in range(df.shape[1]):
                cnt_coord.iloc[i][j] = df.loc[cl == i].iloc[:, [j]].mean()
        centroids = cnt_coord
        return centroids
    

    cnt = centroids_init(df, k)
    if vis: visualise(df, cnt)
    cl = get_new_clusters(df, cnt)
    cnt_new = update_centroids(df, cnt, cl,  k)
    if vis: visualise(df, cnt, cl)
    
    itr = 1
    while (cnt != cnt_new).values.any() and itr < 40:
        cl = get_new_clusters(df, cnt_new)
        cnt = cnt_new
        cnt_new = update_centroids(df, cnt, cl, k)
        if vis and itr % vis == 0: visualise(df, cnt, cl)
        itr += 1
    if vis: visualise(df, cnt, cl)
    if vis: print("centroids:\n",cnt_new)
    return cl

# %%
kMeans2(df, 4, vis=8);
# Out:
# centroids:
#            X         Y
# 0 -0.080145 -0.068477
# 1 -1.114944 -1.111552
# 2 -1.029146  0.957281
# 3  0.945967  0.925046

# %%
kMeans2(df, 3, vis=4);
# Out:
# centroids:
#            X         Y
# 0 -0.921320  0.825428
# 1  0.760832  0.687891
# 2 -0.880855 -0.922759

# %%
kMeans2(df, 2, vis=4);
# Out:
# centroids:
#            X         Y
# 0 -0.928881 -0.162133
# 1  0.609670  0.768800

# %% [markdown]
# ## 2. Cancer dataset

# %%
df2 = pd.read_csv('cancer.csv')
df2.shape
# Out:
# (569, 31)

# %%
def get_purity(df, k, norm = False):
    Y = df.loc[:,'label']
    X = df.drop(['label'], axis = 1)
    if norm: 
        X = pd.DataFrame(MinMaxScaler().fit_transform(X), columns=list(range(1,31)))
    
    #print(f"{k} start")
    CL = kMeans2(X, k)
    #print(f"{k} check")
    data = pd.DataFrame({'label': Y,'cl': CL})
    data = data.sort_values(by=['cl'])
    
    est = []
    for i in range(k):
        # print(i, data.loc[data['cl']==i].mode())
        est += [data.loc[data['cl']==i].mode()['label'].values[0] for _ in range(sum(data['cl'] == i))]
        
    data['est'] = est
    n = len(Y)
    return sum(data['est'] == data['label'])/n

# %%
purity = []
for j in range(2, 11):
    a = get_purity(df2, j)
    print(f"numder of clusters : {j}\n purity: {a}")
    purity.append(a)
# Out:
# numder of clusters : 2
#  purity: 0.8541300527240774
# numder of clusters : 3
#  purity: 0.8664323374340949
# numder of clusters : 4
#  purity: 0.8822495606326889
# numder of clusters : 5
#  purity: 0.8347978910369068
# numder of clusters : 6
#  purity: 0.8910369068541301
# numder of clusters : 7
#  purity: 0.8857644991212654
# numder of clusters : 8
#  purity: 0.8927943760984183
# numder of clusters : 9
#  purity: 0.8840070298769771
# numder of clusters : 10
#  purity: 0.8875219683655536

# %%
n_purity = []
for j in range(2, 11):
    a = get_purity(df2, j, True)
    print(f"numder of clusters : {j}\n purity: {a}")
    n_purity.append(a)
# Out:
# numder of clusters : 2
#  purity: 0.8910369068541301
# numder of clusters : 3
#  purity: 0.8875219683655536
# numder of clusters : 4
#  purity: 0.9033391915641477
# numder of clusters : 5
#  purity: 0.8980667838312829
# numder of clusters : 6
#  purity: 0.8998242530755711
# numder of clusters : 7
#  purity: 0.8945518453427065
# numder of clusters : 8
#  purity: 0.8681898066783831
# numder of clusters : 9
#  purity: 0.9015817223198594
# numder of clusters : 10
#  purity: 0.8857644991212654

# %%
x = np.arange(2, 11)

plt.plot(x, purity)
plt.plot(x, n_purity)

plt.legend(['data', 'normolised data'], loc='upper left')

plt.show()
